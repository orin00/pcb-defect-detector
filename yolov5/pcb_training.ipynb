# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...

# %%
# %cd yolov5
# Out:
# D:\final_project\yolov5

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: gitpython>=3.1.30 in c:\users\user\anaconda3\envs\pcb_env\lib\site-packages (from -r requirements.txt (line 5)) (3.1.46)
# Requirement already satisfied: matplotlib>=3.3 in c:\users\user\anaconda3\envs\pcb_env\lib\site-packages (from -r requirements.txt (line 6)) (3.10.8)
# Requirement already satisfied: numpy>=1.23.5 in c:\users\user\anaconda3\envs\pcb_env\lib\site-packages (from -r requirements.txt (line 7)) (2.3.5)
# Requirement already satisfied: opencv-python>=4.1.1 in c:\users\user\anaconda3\envs\pcb_env\lib\site-packages (from -r requirements.txt (line 8)) (4.13.0.90)
# Requirement already satisfied: pillow>=10.3.0 in c:\users\user\anaconda3\envs\pcb_env\lib\site-packages (from -r requirements.txt (line 9)) (11.1.0)
# Requirement already satisfied: psutil in c:\users\user\anaconda3\envs\pcb_env\lib\site-packages (from -r requirements.txt (line 10)) (7.2.1)
# Requirement already satisfied: PyYAML>=5.3.1 in c:\users\user\anaconda3\envs\pcb_env\lib\site-packages (from -r requirements.txt (line 11)) (6.0.3)
# Requirement already satisfied: requests>=2.32.2 in c:\users\user\anaconda3\envs\pcb_env\lib\site-packages (from -r requirements.txt (line 12)) (2.32.5)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\user\anaconda3\envs\pcb_env\lib\site-packages (from -r requirements.txt (line 13)) (1.17.0)
# Requirement already satisfied: thop>=0.1.1 in c:\users\user\anaconda3\envs\pcb_env\lib\site-packages (from -r requirements.txt (line 14)) (0.1.1.post2209072238)
# Requirement already satisfied: torch>=1.8.0 in c:\users\user\anaconda3\envs\pcb_env\lib\site-packages (from -r requirements.txt (line 15)) (2.5.1+cu121)
# Requirement already satisfied: torchvision>=0.9.0 in c:\users\user\anaconda3\envs\pcb_env\lib\site-packages (from -r requirements.txt (line 16)) (0.20.1+cu121)
# Requirement already satisfied: tqdm>=4.66.3 in c:\users\user\anaconda3\envs\pcb_env\lib\site-packages (from -r requirements.txt (line 17)) (4.67.1)
# Requirement already satisfied: ultralytics>=8.2.64 in c:\users\user\anaconda3\envs\pcb_env\lib\site-packages (from -r requirements.txt (line 18)) (8.4.6)
# Requirement already satisfied: pandas>=1.1.4 in c:\users\user\anaconda3\envs\pcb_env\lib\site-packages (from -r requirements.txt (line 27)) (2.3.3)
# Requirement already satisfied: seaborn>=0.11.0 in c:\users\user\anaconda3\envs\pcb_env\lib\site-packages (from -r requirements.txt (line 28)) (0.13.2)
# Requirement already satisfied: packaging in c:\users\user\anaconda3\envs\pcb_env\lib\site-packages (from -r requirements.txt (line 42)) (25.0)
# Requirement already satisfied: setuptools>=70.0.0 in c:\users\user\anaconda3\envs\pcb_env\lib\site-packages (from -r requirements.txt (line 43)) (80.9.0)
# Requirement already satisfied: urllib3>=2.6.0 in c:\users\user\anaconda3\envs\pcb_env\lib\site-packages (from -r requirements.txt (line 51)) (2.6.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\user\anaconda3\envs\pcb_env\lib\site-packages (from gitpython>=3.1.30->-r requirements.txt (line 5)) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\user\anaconda3\envs\pcb_env\lib\site-packages (from gitdb<5,>=4.0.1->gitpython>=3.1.30->-r requirements.txt (line 5)) (5.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user\anaconda3\envs\pcb_env\lib\site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\anaconda3\envs\pcb_env\lib\site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\anaconda3\envs\pcb_env\lib\site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (4.61.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\user\anaconda3\envs\pcb_env\lib\site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (1.4.9)
# Requirement already satisfied: pyparsing>=3 in c:\users\user\anaconda3\envs\pcb_env\lib\site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\anaconda3\envs\pcb_env\lib\site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\user\anaconda3\envs\pcb_env\lib\site-packages (from requests>=2.32.2->-r requirements.txt (line 12)) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\anaconda3\envs\pcb_env\lib\site-packages (from requests>=2.32.2->-r requirements.txt (line 12)) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\envs\pcb_env\lib\site-packages (from requests>=2.32.2->-r requirements.txt (line 12)) (2026.1.4)
# Requirement already satisfied: filelock in c:\users\user\anaconda3\envs\pcb_env\lib\site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\user\anaconda3\envs\pcb_env\lib\site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (4.15.0)
# Requirement already satisfied: networkx in c:\users\user\anaconda3\envs\pcb_env\lib\site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (3.6.1)
# Requirement already satisfied: jinja2 in c:\users\user\anaconda3\envs\pcb_env\lib\site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (3.1.6)
# Requirement already satisfied: fsspec in c:\users\user\anaconda3\envs\pcb_env\lib\site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (2025.12.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\user\anaconda3\envs\pcb_env\lib\site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\user\anaconda3\envs\pcb_env\lib\site-packages (from sympy==1.13.1->torch>=1.8.0->-r requirements.txt (line 15)) (1.3.0)
# Requirement already satisfied: colorama in c:\users\user\anaconda3\envs\pcb_env\lib\site-packages (from tqdm>=4.66.3->-r requirements.txt (line 17)) (0.4.6)
# Requirement already satisfied: polars>=0.20.0 in c:\users\user\anaconda3\envs\pcb_env\lib\site-packages (from ultralytics>=8.2.64->-r requirements.txt (line 18)) (1.37.1)
# Requirement already satisfied: ultralytics-thop>=2.0.18 in c:\users\user\anaconda3\envs\pcb_env\lib\site-packages (from ultralytics>=8.2.64->-r requirements.txt (line 18)) (2.0.18)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\anaconda3\envs\pcb_env\lib\site-packages (from pandas>=1.1.4->-r requirements.txt (line 27)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\user\anaconda3\envs\pcb_env\lib\site-packages (from pandas>=1.1.4->-r requirements.txt (line 27)) (2025.3)
# Requirement already satisfied: polars-runtime-32==1.37.1 in c:\users\user\anaconda3\envs\pcb_env\lib\site-packages (from polars>=0.20.0->ultralytics>=8.2.64->-r requirements.txt (line 18)) (1.37.1)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\envs\pcb_env\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3->-r requirements.txt (line 6)) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\user\anaconda3\envs\pcb_env\lib\site-packages (from jinja2->torch>=1.8.0->-r requirements.txt (line 15)) (2.1.5)

# %%
# !pip install pandas requests tqdm
# Out:
# Requirement already satisfied: pandas in c:\users\user\anaconda3\envs\pcb_env\lib\site-packages (2.3.3)
# Requirement already satisfied: requests in c:\users\user\anaconda3\envs\pcb_env\lib\site-packages (2.32.5)
# Requirement already satisfied: tqdm in c:\users\user\anaconda3\envs\pcb_env\lib\site-packages (4.67.1)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\user\anaconda3\envs\pcb_env\lib\site-packages (from pandas) (2.3.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\user\anaconda3\envs\pcb_env\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\anaconda3\envs\pcb_env\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\user\anaconda3\envs\pcb_env\lib\site-packages (from pandas) (2025.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\user\anaconda3\envs\pcb_env\lib\site-packages (from requests) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\anaconda3\envs\pcb_env\lib\site-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\anaconda3\envs\pcb_env\lib\site-packages (from requests) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\envs\pcb_env\lib\site-packages (from requests) (2026.1.4)
# Requirement already satisfied: colorama in c:\users\user\anaconda3\envs\pcb_env\lib\site-packages (from tqdm) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\envs\pcb_env\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import os
import xml.etree.ElementTree as ET
from tqdm import tqdm

# %%
# 경로 설정
BASE_DIR = r"D:\final_project\VOC_PCB"
XML_DIR = os.path.join(BASE_DIR, "Annotations")
LABEL_DIR = os.path.join(BASE_DIR, "labels")  # 새로 생성될 폴더
IMAGE_DIR = os.path.join(BASE_DIR, "JPEGImages")

# 결함 유형 정의 (인덱스 순서 중요)
classes = ["short", "missing_hole", "mouse_bite", "open_circuit", "spurious_copper", "spur"]

# labels 폴더가 없으면 생성
if not os.path.exists(LABEL_DIR):
    os.makedirs(LABEL_DIR)

def convert_coordinates(size, box):
    """VOC 좌표를 YOLO 정규화 좌표로 변환"""
    dw = 1. / size[0]
    dh = 1. / size[1]
    x = (box[0] + box[1]) / 2.0
    y = (box[2] + box[3]) / 2.0
    w = box[1] - box[0]
    h = box[3] - box[2]
    return (x * dw, y * dh, w * dw, h * dh)

# XML 파일 전체 변환 작업
print("Converting XML annotations to YOLO format...")
xml_files = [f for f in os.listdir(XML_DIR) if f.endswith(".xml")]

for xml_file in tqdm(xml_files):
    tree = ET.parse(os.path.join(XML_DIR, xml_file))
    root = tree.getroot()
    
    size = root.find("size")
    width = int(size.find("width").text)
    height = int(size.find("height").text)

    file_id = os.path.splitext(xml_file)[0]
    with open(os.path.join(LABEL_DIR, f"{file_id}.txt"), "w") as out_file:
        for obj in root.iter("object"):
            cls_name = obj.find("name").text
            if cls_name not in classes:
                continue
            
            cls_id = classes.index(cls_name)
            xmlbox = obj.find("bndbox")
            b = (float(xmlbox.find("xmin").text), float(xmlbox.find("xmax").text),
                 float(xmlbox.find("ymin").text), float(xmlbox.find("ymax").text))
            
            bb = convert_coordinates((width, height), b)
            # <class_id> <x_center> <y_center> <width> <height>
            out_file.write(f"{cls_id} {' '.join([f'{a:.6f}' for a in bb])}\n")

print("Conversion complete.")
# Out:
# Converting XML annotations to YOLO format...
# 100%|██████████████████████████████████████████████████████████████████████████| 10668/10668 [00:05<00:00, 1838.68it/s]
# Conversion complete.

# %%
import yaml

data_yaml = {
    'path': BASE_DIR,
    'train': 'train.txt',
    'val': 'val.txt',
    'test': 'test.txt',
    'nc': 6,
    'names': classes
}

with open(os.path.join(BASE_DIR, 'dataset.yaml'), 'w') as f:
    yaml.dump(data_yaml, f, default_flow_style=False)

print(f"dataset.yaml created at {BASE_DIR}")
# Out:
# dataset.yaml created at D:\final_project\VOC_PCB

# %%
# 현재 경로가 yolov5 폴더인지 다시 한번 확인
import os
print(f"현재 작업 경로: {os.getcwd()}")
# Out:
# 현재 작업 경로: D:\final_project\yolov5

# %%
import os

# 경로 설정 (사용자 환경에 맞춤)
BASE_DIR = r"D:\final_project\VOC_PCB"
IMAGE_DIR = os.path.join(BASE_DIR, "JPEGImages")

# 수정할 리스트 파일들
target_files = ['train.txt', 'val.txt', 'test.txt']

for target in target_files:
    file_path = os.path.join(BASE_DIR, target)
    
    if not os.path.exists(file_path):
        print(f"파일을 찾을 수 없습니다: {file_path}")
        continue
        
    # 기존 파일 읽기
    with open(file_path, 'r') as f:
        lines = f.readlines()
    
    # 경로 업데이트: 파일명 -> D:\final_project\VOC_PCB\JPEGImages\파일명.jpg
    new_lines = []
    for line in lines:
        name = line.strip()
        if not name:
            continue
        # 확장자가 붙어있지 않다면 .jpg를 붙여 절대 경로 생성
        if not name.endswith('.jpg'):
            full_path = os.path.join(IMAGE_DIR, f"{name}.jpg")
        else:
            full_path = os.path.join(IMAGE_DIR, name)
        new_lines.append(full_path + '\n')
    
    # 수정된 내용으로 덮어쓰기
    with open(file_path, 'w') as f:
        f.writelines(new_lines)

print("모든 경로가 절대 경로로 업데이트되었습니다.")
# Out:
# 모든 경로가 절대 경로로 업데이트되었습니다.

# %%
import os
import glob

# 1. 경로 설정
BASE_DIR = r"D:\final_project\VOC_PCB"
# 폴더 이름을 'images'로 변경한 후의 경로
IMAGE_DIR = os.path.join(BASE_DIR, "images")

# 2. 기존 잘못된 캐시 파일(.cache) 삭제 (매우 중요)
cache_files = glob.glob(os.path.join(BASE_DIR, "*.cache"))
for cf in cache_files:
    try:
        os.remove(cf)
        print(f"삭제 완료: {cf}")
    except:
        pass

# 3. train.txt, val.txt, test.txt 내 경로를 새 images 폴더로 업데이트
target_files = ['train.txt', 'val.txt', 'test.txt']

for target in target_files:
    file_path = os.path.join(BASE_DIR, target)
    if os.path.exists(file_path):
        with open(file_path, 'r') as f:
            lines = f.readlines()
        
        new_lines = []
        for line in lines:
            # 파일명만 추출해서 D:\final_project\VOC_PCB\images\파일명.jpg 로 재구성
            fname = os.path.basename(line.strip())
            if not fname.lower().endswith('.jpg'):
                fname += '.jpg'
            new_lines.append(os.path.join(IMAGE_DIR, fname) + '\n')
            
        with open(file_path, 'w') as f:
            f.writelines(new_lines)

print("데이터셋 경로 업데이트 및 캐시 삭제가 완료되었습니다.")
# Out:
# 삭제 완료: D:\final_project\VOC_PCB\train.cache
# 데이터셋 경로 업데이트 및 캐시 삭제가 완료되었습니다.
